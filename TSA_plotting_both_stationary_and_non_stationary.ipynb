# %% [markdown]
# <a href="https://colab.research.google.com/github/alinapradhan/Time-series-analysis-plotting/blob/main/TSA_plotting_both_stationary_and_non_stationary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## plotting TSA both stationary and non stationary on R

#load necessary data
install.packages(c("tseries","zoo"))
 # You only need to run this once
library(tseries)
library(zoo)
#load in dataset
data("lh")

#1.visiual inspection
plot(lh, main="guine pigs tibia lenghts")

#2.summary stats
summary(lh)

#3.adf test
adf_test <-adf.test(lh)
print(adf_test)
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘quadprog’, ‘quantmod’
#
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    1.40    2.00    2.30    2.40    2.75    3.50
# 	Augmented Dickey-Fuller Test
#
# data:  lh
# Dickey-Fuller = -3.558, Lag order = 3, p-value = 0.04624
# alternative hypothesis: stationary
# Plot with title “guine pigs tibia lenghts”

# %%
#genrate time vector
t<-1:300

#genrate stainary time series
set.seed(123)
y_statinary <- rnorm(length(t), mean = 0, sd =1)
y_statinary<- y_statinary/max(y_statinary)

# %%
#genrate non statinary time seriws with a trend
set.seed(456)
y_trend<-cumsum(rnorm(length(t),mean = 0, sd= 4))+t /100
y_trend<- y_trend / max(y_trend)

# %%
#set up more attraaction layout for the plots
par(mfcol =c(2,3), mar = c(4,4,2,1))

# %%
#plot statinmary time series
plot(t,y_statinary, type = 'l', col='darkgreen', xlab = "Time(t)", ylab = "y(t)", main="statinary time series ",
     xex.main =1.2, cex.lab=1.1)
# Out:
# Warning message in plot.window(...):
# “"xex.main" is not a graphical parameter”
# Warning message in plot.xy(xy, type, ...):
# “"xex.main" is not a graphical parameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"xex.main" is not a graphical parameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"xex.main" is not a graphical parameter”
# Warning message in box(...):
# “"xex.main" is not a graphical parameter”
# Warning message in title(...):
# “"xex.main" is not a graphical parameter”
# Plot with title “statinary time series ”

# %%
#acf for statinary time series
acf_y_statinary <- acf(y_statinary, lag.max = length(y_statinary),plot=FALSE)
plot(acf_y_statinary, main='ACF-Statinary time series', cex.mioan = 1.2, cex.lab=1.1)
# Out:
# Warning message in plot.window(...):
# “"cex.mioan" is not a graphical parameter”
# Warning message in plot.xy(xy, type, ...):
# “"cex.mioan" is not a graphical parameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"cex.mioan" is not a graphical parameter”
# Warning message in axis(side = side, at = at, labels = labels, ...):
# “"cex.mioan" is not a graphical parameter”
# Warning message in box(...):
# “"cex.mioan" is not a graphical parameter”
# Warning message in title(...):
# “"cex.mioan" is not a graphical parameter”
# Plot with title “ACF-Statinary time series”

# %%
#Non-stationary time series with Trend
plot(t,y_trend, type = 'l',col = 'steelblue', xlab = "time (t)",ylab = "y(t)",main = "Non-stationary time series with Trend", cex.lab = 1.1)
# Out:
# Plot with title “Non-stationary time series with Trend”

# %%
#ACF - Non-stationary time series with trend
acf_y_trend <- acf(y_trend, lag.max = length(y_trend),plot = FALSE)
plot(acf_y_trend,main = 'ACF - Non-stationary time series with trend',cex.main = 1.2,cex.lab = 1.1)
# Out:
# Plot with title “ACF - Non-stationary time series with trend”
